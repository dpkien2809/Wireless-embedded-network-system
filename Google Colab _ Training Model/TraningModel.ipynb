# %% [markdown]
# # Chuẩn bị data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression

# %%
csv_file_path = '/content/drive/MyDrive/Nhung/Data_Nhung.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)
df.shape
# Out:
# (26408, 4)

# %%
column_name = 'Label'

# Sử dụng phương thức value_counts() để đếm số lần xuất hiện của mỗi giá trị
value_counts = df[column_name].value_counts()

# In ra tên giá trị cùng với số lần xuất hiện
for value, count in value_counts.iteritems():
    print(f"{value}: {count}")
# Out:
# lightly_sunlit: 7361
# blazing_sun: 6797
# Cold fog: 6348
# Sunny: 2897
# pleasantly cool: 2587
# Rainy: 418
# <ipython-input-4-b1fed1c344d0>:7: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for value, count in value_counts.iteritems():

# %%
test =  df.iloc[:, :-1].values
check = np.array(test)
mean_values_column = np.mean(check, axis=0)
print("Giá trị trung bình trên các cột:", mean_values_column)
# Out:
# Giá trị trung bình trên các cột: [  30.13210997   67.2376314  1011.57199636]

# %%
df.isna().sum()
# Out:
# Temp        0
# Humidity    0
# Presure     0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming filtered_data is the path to your CSV file
#csv_file_path = '/content/drive/MyDrive/Nhung/Night-11-10-2023.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Plot all columns in a single figure
plt.figure(figsize=(10, 6))  # You can adjust the figure size as needed


plt.plot(df['Presure'])
plt.xlabel('Chỉ số của mảng')
plt.ylabel('Giá trị')
plt.title('Biểu đồ giá trị của mảng')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming filtered_data is the path to your CSV file
#csv_file_path = '/content/drive/MyDrive/Nhung/Night-11-10-2023.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Plot all columns in a single figure
plt.figure(figsize=(10, 6))  # You can adjust the figure size as needed


plt.plot(df['Presure'])
plt.xlabel('Chỉ số của mảng')
plt.ylabel('Giá trị')
plt.title('Biểu đồ giá trị của mảng')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming filtered_data is the path to your CSV file
csv_file_path1 = '/content/drive/MyDrive/Nhung/Data_Nhung.csv'

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path1)

# Plot all columns in a single figure
plt.figure(figsize=(10, 6))  # You can adjust the figure size as needed


plt.plot(df['Presure'])
plt.xlabel('Chỉ số của mảng')
plt.ylabel('Giá trị')
plt.title('Biểu đồ giá trị của mảng')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
data = pd.read_csv('/content/drive/MyDrive/Nhung/Data_Nhung.csv')
data.head()
X = data.iloc[:, :-1].values
Y = data.iloc[:, -1].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=.2, random_state=41)

# %%
# !pip install micromlgen
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for micromlgen: filename=micromlgen-1.1.28-py3-none-any.whl size=32152 sha256=ecdb4572f2539cc48c12565f03f93f2327447796efc066aef57cfdc40e84b6dc
#   Stored in directory: /root/.cache/pip/wheels/97/54/64/5d82c310920abe1be0d120313ceb9e12c88f5701f53f6ed248
# Successfully built micromlgen
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
import tensorflow as tf
from tensorflow import keras

# %%
label_encoder = preprocessing.LabelEncoder()
data = pd.read_csv('/content/drive/MyDrive/Nhung/Data_Nhung.csv')
# Encode labels in column 'species'.
data['Label']= label_encoder.fit_transform(data['Label'])
data['Label'].unique()

# %%
from micromlgen import port
model = DecisionTreeClassifier(criterion="entropy",random_state=41)
model.fit(X_train, y_train)

y_hat = model.predict(X_test)
print(classification_report(y_test, y_hat))
print(accuracy_score(y_test,y_hat))
print(port(model))

# %%
regressors = [ DecisionTreeClassifier(criterion="entropy",random_state=41),
               svm.SVC(gamma='auto',C=1.0, kernel='rbf'),
               RandomForestClassifier(n_estimators=100, max_depth=10, random_state=1),
 ]

# %%
test_df  = pd.read_csv('/content/drive/MyDrive/Nhung/Test.csv')

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from imblearn.pipeline import Pipeline
for i in regressors:
   pipeline = Pipeline(steps = [
    ('scaler', StandardScaler()),
    ('smote',SMOTE(sampling_strategy='minority')),
    ('SVM',i)
])
   pipeline.fit(X_train, y_train)
   y_hat = pipeline.predict(X_test)
   print(i)
   print(classification_report(y_test, y_hat))
   print(accuracy_score(y_test,y_hat))

   #predictions = pipeline.predict(test_df)
   #results_df = pd.DataFrame({'Label': predictions})
   #pd.DataFrame(results_df).to_csv(f'pred{i}.csv', index=False)
   import matplotlib.pyplot as plt
   from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
   ConfusionMatrixDisplay
   cm = confusion_matrix(y_test, y_hat)
   disp = ConfusionMatrixDisplay(confusion_matrix=cm)
   disp.plot()
   plt.show()
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=41)
#                  precision    recall  f1-score   support
#
#        Cold fog       1.00      1.00      1.00      1267
#           Rainy       1.00      1.00      1.00        82
#           Sunny       0.99      0.99      0.99       575
#     blazing_sun       1.00      0.99      1.00      1377
#  lightly_sunlit       0.99      1.00      1.00      1474
# pleasantly cool       1.00      1.00      1.00       507
#
#        accuracy                           1.00      5282
#       macro avg       1.00      1.00      1.00      5282
#    weighted avg       1.00      1.00      1.00      5282
#
# 0.9965921999242711
# SVC(gamma='auto')
#                  precision    recall  f1-score   support
#
#        Cold fog       0.99      0.99      0.99      1267
#           Rainy       1.00      1.00      1.00        82
#           Sunny       0.99      0.99      0.99       575
#     blazing_sun       1.00      1.00      1.00      1377
# ...
